# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv")

# %%
df.shape[:]
# Out:
# (53392, 33)

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
# 3       2011     2011           AL      Alabama
# 4       2011     2011           AL      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   53392 non-null  int64
#  1   YearEnd                     53392 non-null  int64
#  2   LocationAbbr                53392 non-null  object
#  3   LocationDesc                53392 non-null  object
#  4   Datasource                  53392 non-null  object
#  5   Class                       53392 non-null  object
#  6   Topic                       53392 non-null  object
#  7   Question                    53392 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             53392 non-null  object
#  10  Data_Value                  48346 non-null  float64
#  11  Data_Value_Alt              48346 non-null  float64
#  12  Data_Value_Footnote_Symbol  5046 non-null   object
# ...

# %%
df["YearStart"].unique()
# Out:
# array([2011, 2012, 2014, 2013, 2015, 2016], dtype=int64)

# %%
print(df["LocationDesc"].nunique())
print(df["LocationID"].nunique())
# Out:
# 55
# 55

# %%
print("data_source" ,df["Datasource"].unique())
print("class:" ,df["Class"].unique())
print("class_id:" ,df["ClassID"].unique())
# Out:
# data_source ['Behavioral Risk Factor Surveillance System']
# class: ['Obesity / Weight Status' 'Fruits and Vegetables' 'Physical Activity']
# class_id: ['OWS' 'FV' 'PA']

# %%
print("topic:" ,df["Topic"].unique())
print(df["Topic"].unique().sum())
print("topic_id:" ,df["TopicID"].unique())
# Out:
# topic: ['Obesity / Weight Status' 'Fruits and Vegetables - Behavior'
#  'Physical Activity - Behavior']
# Obesity / Weight StatusFruits and Vegetables - BehaviorPhysical Activity - Behavior
# topic_id: ['OWS1' 'FV1' 'PA1']

# %%
print(df["Question"].nunique())
print("Questions" ,df["Question"].unique())
print("Questions_id" ,df["QuestionID"].unique())
# Out:
# 9
# Questions ['Percent of adults aged 18 years and older who have obesity'
#  'Percent of adults aged 18 years and older who have an overweight classification'
#  'Percent of adults who report consuming fruit less than one time daily'
#  'Percent of adults who report consuming vegetables less than one time daily'
#  'Percent of adults who engage in muscle-strengthening activities on 2 or more days a week'
#  'Percent of adults who achieve at least 150 minutes a week of moderate-intensity aerobic physical activity or 75 minutes a week of vigorous-intensity aerobic activity (or an equivalent combination)'
#  'Percent of adults who achieve at least 150 minutes a week of moderate-intensity aerobic physical activity or 75 minutes a week of vigorous-intensity aerobic physical activity and engage in muscle-strengthening activities on 2 or more days a week'
# ...

# %%
print("Locations_id:" ,df["LocationID"].nunique())
print("Strtatification_category_1:" ,df["StratificationCategory1"].unique())
print("\n")
print("Strtatification_1:" ,df["Stratification1"].unique())
print("\n")
print("data_value_Type" ,df["Data_Value_Type"].unique())
# Out:
# Locations_id: 55
# Strtatification_category_1: ['Total' 'Gender' 'Education' 'Age (years)' 'Income' 'Race/Ethnicity']
#
#
# Strtatification_1: ['Total' 'Male' 'Female' 'Less than high school' 'High school graduate'
#  'Some college or technical school' 'College graduate' '18 - 24' '25 - 34'
#  '35 - 44' '45 - 54' '55 - 64' '65 or older' 'Less than $15,000'
#  '$15,000 - $24,999' '$25,000 - $34,999' '$35,000 - $49,999'
#  '$50,000 - $74,999' '$75,000 or greater' 'Data not reported'
#  'Non-Hispanic White' 'Non-Hispanic Black' 'Hispanic' 'Asian'
#  'Hawaiian/Pacific Islander' 'American Indian/Alaska Native'
#  '2 or more races' 'Other']
#
#
# data_value_Type ['Value']

# %%
df.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               53392
# Data_Value_Type                   0
# Data_Value                     5046
# Data_Value_Alt                 5046
# Data_Value_Footnote_Symbol    48346
# Data_Value_Footnote           48346
# Low_Confidence_Limit           5046
# High_Confidence_Limit          5046
# Sample_Size                    5046
# Total                         51485
# Age(years)                    41954
# Education                     45764
# Gender                        49578
# Income                        40043
# Race/Ethnicity                38136
# GeoLocation                    1008
# ClassID                           0
# TopicID                           0
# ...

# %%
df = df.dropna(subset=['Sample_Size'])
df.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               48346
# Data_Value_Type                   0
# Data_Value                        0
# Data_Value_Alt                    0
# Data_Value_Footnote_Symbol    48346
# Data_Value_Footnote           48346
# Low_Confidence_Limit              0
# High_Confidence_Limit             0
# Sample_Size                       0
# Total                         46439
# Age(years)                    36908
# Education                     40718
# Gender                        44532
# Income                        34997
# Race/Ethnicity                38136
# GeoLocation                    1008
# ClassID                           0
# TopicID                           0
# ...

# %%
df.shape
# Out:
# (48346, 33)

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
# 3       2011     2011           AL      Alabama
# 4       2011     2011           AL      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=df.corr(),annot=True, lw = 1)
# Out:
# C:\Users\Rathod Rohit\AppData\Local\Temp\ipykernel_13848\2362052783.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),annot=True, lw = 1)
# <Axes: >

# %%
df_final = df[['YearStart','YearEnd','LocationDesc','Topic','Question','Data_Value',
               'Total','Age(years)','Education','Gender','Income','Race/Ethnicity','QuestionID','Stratification1']]

# %%
df_final.head()
# Out:
#    YearStart  YearEnd LocationDesc                    Topic  \
# 0       2011     2011      Alabama  Obesity / Weight Status
# 1       2011     2011      Alabama  Obesity / Weight Status
# 2       2011     2011      Alabama  Obesity / Weight Status
# 3       2011     2011      Alabama  Obesity / Weight Status
# 4       2011     2011      Alabama  Obesity / Weight Status
#
#                                             Question  Data_Value  Total  \
# 0  Percent of adults aged 18 years and older who ...        32.0  Total
# 1  Percent of adults aged 18 years and older who ...        32.3    NaN
# 2  Percent of adults aged 18 years and older who ...        31.8    NaN
# 3  Percent of adults aged 18 years and older who ...        33.6    NaN
# 4  Percent of adults aged 18 years and older who ...        32.8    NaN
#
#   Age(years)              Education  Gender Income Race/Ethnicity QuestionID  \
# 0        NaN                    NaN     NaN    NaN            NaN       Q036
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=df_final.corr(),annot=True, lw = 1)
# Out:
# C:\Users\Rathod Rohit\AppData\Local\Temp\ipykernel_13848\2228833376.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df_final.corr(),annot=True, lw = 1)
# <Axes: >

# %%
distinct_questions = df_final['Question'].unique()
question_to_integer = {question: i + 1 for i, question in enumerate(distinct_questions)}

df_final_copy = df_final.copy()

df_final_copy['question_id'] = df_final_copy['Question'].map(question_to_integer)

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df_final["Age(years)"], y=df_final["Data_Value"])
# Out:
# <Axes: xlabel='Age(years)', ylabel='Data_Value'>

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df_final["Gender"], y=df_final["Data_Value"])
# Out:
# <Axes: xlabel='Gender', ylabel='Data_Value'>

# %%
df_final = df_final[df_final['Topic'] == 'Obesity / Weight Status']
df_final.shape
# Out:
# (16254, 14)

# %%
df_final.drop(['Topic','Question','QuestionID','Stratification1','YearEnd'], axis=1, inplace=True)

# %%
plt.figure(figsize=(15,20))
sns.scatterplot(x=df_final["Education"], y=df_final["Data_Value"])
# Out:
# <Axes: xlabel='Education', ylabel='Data_Value'>

# %%
sns.relplot(data=df_final, x='Education', y='Data_Value', kind='line', col='YearStart',aspect = 2,col_wrap = 2)

# %%
plt.figure(figsize=(15,20))
sns.scatterplot(x=df_final['Race/Ethnicity'],y=df_final['Data_Value'])
# Out:
# <Axes: xlabel='Race/Ethnicity', ylabel='Data_Value'>

# %%
sns.barplot(data=df_final, x='Age(years)', y='Data_Value', palette='Blues')
plt.xlabel('Age(years)')
plt.ylabel('Data_Value')
plt.ylim(1, 50)
# Out:
# (1.0, 50.0)

# %%
sns.set(style="whitegrid")  
sns.boxplot(df_final,x='Income', y='Data_Value', palette='Blues')
plt.xlabel('Income')
plt.ylabel('Data_Value')
plt.title('Box Plot of Data_Value vs. Income')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Less than $15,000'),
#   Text(1, 0, '$15,000 - $24,999'),
#   Text(2, 0, '$25,000 - $34,999'),
#   Text(3, 0, '$35,000 - $49,999'),
#   Text(4, 0, '$50,000 - $74,999'),
#   Text(5, 0, '$75,000 or greater'),
#   Text(6, 0, 'Data not reported')])

# %% [markdown]
# # One Hot Encoder

# %%
df_final_ohe = pd.get_dummies(data=df_final ,columns=['YearStart','LocationDesc','Total','Age(years)','Education','Gender','Income','Race/Ethnicity'], drop_first=True)
df_final_ohe
# Out:
#        Data_Value  YearStart_2012  YearStart_2013  YearStart_2014  \
# 0            32.0               0               0               0
# 1            32.3               0               0               0
# 2            31.8               0               0               0
# 3            33.6               0               0               0
# 4            32.8               0               0               0
# ...           ...             ...             ...             ...
# 51842        32.6               0               0               0
# 51843        31.8               0               0               0
# 51844        21.3               0               0               0
# 51845        34.3               0               0               0
# 51846        32.7               0               0               0
#
#        YearStart_2015  YearStart_2016  LocationDesc_Alaska  \
# 0                   0               0                    0
# ...

# %%
df_final_ohe.shape
df_final_ohe.columns
# Out:
# Index(['Data_Value', 'YearStart_2012', 'YearStart_2013', 'YearStart_2014',
#        'YearStart_2015', 'YearStart_2016', 'LocationDesc_Alaska',
#        'LocationDesc_Arizona', 'LocationDesc_Arkansas',
#        'LocationDesc_California', 'LocationDesc_Colorado',
#        'LocationDesc_Connecticut', 'LocationDesc_Delaware',
#        'LocationDesc_District of Columbia', 'LocationDesc_Florida',
#        'LocationDesc_Georgia', 'LocationDesc_Guam', 'LocationDesc_Hawaii',
#        'LocationDesc_Idaho', 'LocationDesc_Illinois', 'LocationDesc_Indiana',
#        'LocationDesc_Iowa', 'LocationDesc_Kansas', 'LocationDesc_Kentucky',
#        'LocationDesc_Louisiana', 'LocationDesc_Maine', 'LocationDesc_Maryland',
#        'LocationDesc_Massachusetts', 'LocationDesc_Michigan',
#        'LocationDesc_Minnesota', 'LocationDesc_Mississippi',
#        'LocationDesc_Missouri', 'LocationDesc_Montana',
#        'LocationDesc_National', 'LocationDesc_Nebraska', 'LocationDesc_Nevada',
# ...

# %%
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df_final_ohe.columns
# Out:
# Index(['Data_Value', 'YearStart_2012', 'YearStart_2013', 'YearStart_2014',
#        'YearStart_2015', 'YearStart_2016', 'LocationDesc_Alaska',
#        'LocationDesc_Arizona', 'LocationDesc_Arkansas',
#        'LocationDesc_California', 'LocationDesc_Colorado',
#        'LocationDesc_Connecticut', 'LocationDesc_Delaware',
#        'LocationDesc_District of Columbia', 'LocationDesc_Florida',
#        'LocationDesc_Georgia', 'LocationDesc_Guam', 'LocationDesc_Hawaii',
#        'LocationDesc_Idaho', 'LocationDesc_Illinois', 'LocationDesc_Indiana',
#        'LocationDesc_Iowa', 'LocationDesc_Kansas', 'LocationDesc_Kentucky',
#        'LocationDesc_Louisiana', 'LocationDesc_Maine', 'LocationDesc_Maryland',
#        'LocationDesc_Massachusetts', 'LocationDesc_Michigan',
#        'LocationDesc_Minnesota', 'LocationDesc_Mississippi',
#        'LocationDesc_Missouri', 'LocationDesc_Montana',
#        'LocationDesc_National', 'LocationDesc_Nebraska', 'LocationDesc_Nevada',
# ...

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
y_pred2=regr.predict(X_train)
mse = mean_squared_error(y_test, y_pred)
mse2=mean_squared_error(y_train,y_pred2 )
rmse = np.sqrt(mse)
rmse
mse2
# Out:
# 33.562314552207404

# %%
X_train[:1]
y_train[:1]
gg=regr.predict(X_train[:1])
gg
# Out:
# array([[29.49356835]])

# %%
# Generate a download link
download_link = f'<a href="modified_file.csv" download>Click here to download the modified CSV file</a>'

# Display the download link in the notebook
HTML(download_link)
# Out:
#        YearStart    LocationDesc  Data_Value  Total Age(years)  \
# 0           2011         Alabama        32.0  Total        NaN
# 1           2011         Alabama        32.3    NaN        NaN
# 2           2011         Alabama        31.8    NaN        NaN
# 3           2011         Alabama        33.6    NaN        NaN
# 4           2011         Alabama        32.8    NaN        NaN
# ...          ...             ...         ...    ...        ...
# 51842       2016  Virgin Islands        32.6    NaN        NaN
# 51843       2016  Virgin Islands        31.8    NaN        NaN
# 51844       2016  Virgin Islands        21.3    NaN        NaN
# 51845       2016  Virgin Islands        34.3    NaN        NaN
# 51846       2016  Virgin Islands        32.7    NaN        NaN
#
#                    Education  Gender              Income      Race/Ethnicity
# 0                        NaN     NaN                 NaN                 NaN
# ...
