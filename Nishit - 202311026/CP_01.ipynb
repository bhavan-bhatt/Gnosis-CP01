# %%
import pandas as pd

# %%
df = pd.read_csv("Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv")

# %%
df.shape[:]
# Out:
# (53392, 33)

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
# 3       2011     2011           AL      Alabama
# 4       2011     2011           AL      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   53392 non-null  int64
#  1   YearEnd                     53392 non-null  int64
#  2   LocationAbbr                53392 non-null  object
#  3   LocationDesc                53392 non-null  object
#  4   Datasource                  53392 non-null  object
#  5   Class                       53392 non-null  object
#  6   Topic                       53392 non-null  object
#  7   Question                    53392 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             53392 non-null  object
#  10  Data_Value                  48346 non-null  float64
#  11  Data_Value_Alt              48346 non-null  float64
#  12  Data_Value_Footnote_Symbol  5046 non-null   object
# ...

# %%
df["YearStart"].unique()
# Out:
# array([2011, 2012, 2014, 2013, 2015, 2016], dtype=int64)

# %%
df["YearEnd"].unique()
# Out:
# array([2011, 2012, 2014, 2013, 2015, 2016], dtype=int64)

# %%
print(df["LocationDesc"].nunique())
print(df["LocationID"].nunique())
# Out:
# 55
# 55

# %%
print("data_source" ,df["Datasource"].unique())
print("class:" ,df["Class"].unique())
print("class_id:" ,df["ClassID"].unique())
# Out:
# data_source ['Behavioral Risk Factor Surveillance System']
# class: ['Obesity / Weight Status' 'Fruits and Vegetables' 'Physical Activity']
# class_id: ['OWS' 'FV' 'PA']

# %%
print("topic:" ,df["Topic"].unique())
print(df["Topic"].unique().sum())
print("topic_id:" ,df["TopicID"].unique())
# Out:
# topic: ['Obesity / Weight Status' 'Fruits and Vegetables - Behavior'
#  'Physical Activity - Behavior']
# Obesity / Weight StatusFruits and Vegetables - BehaviorPhysical Activity - Behavior
# topic_id: ['OWS1' 'FV1' 'PA1']

# %%
print(df["Question"].nunique())
print("Questions" ,df["Question"].unique())
print("Questions_id" ,df["QuestionID"].unique())
# Out:
# 9
# Questions ['Percent of adults aged 18 years and older who have obesity'
#  'Percent of adults aged 18 years and older who have an overweight classification'
#  'Percent of adults who report consuming fruit less than one time daily'
#  'Percent of adults who report consuming vegetables less than one time daily'
#  'Percent of adults who engage in muscle-strengthening activities on 2 or more days a week'
#  'Percent of adults who achieve at least 150 minutes a week of moderate-intensity aerobic physical activity or 75 minutes a week of vigorous-intensity aerobic activity (or an equivalent combination)'
#  'Percent of adults who achieve at least 150 minutes a week of moderate-intensity aerobic physical activity or 75 minutes a week of vigorous-intensity aerobic physical activity and engage in muscle-strengthening activities on 2 or more days a week'
# ...

# %%
print("Locations_id:" ,df["LocationID"].nunique())
print("Strtatification_category_1:" ,df["StratificationCategory1"].unique())
print("\n")
print("Strtatification_1:" ,df["Stratification1"].unique())
print("\n")
print("data_value_Type" ,df["Data_Value_Type"].unique())
# Out:
# Locations_id: 55
# Strtatification_category_1: ['Total' 'Gender' 'Education' 'Age (years)' 'Income' 'Race/Ethnicity']
#
#
# Strtatification_1: ['Total' 'Male' 'Female' 'Less than high school' 'High school graduate'
#  'Some college or technical school' 'College graduate' '18 - 24' '25 - 34'
#  '35 - 44' '45 - 54' '55 - 64' '65 or older' 'Less than $15,000'
#  '$15,000 - $24,999' '$25,000 - $34,999' '$35,000 - $49,999'
#  '$50,000 - $74,999' '$75,000 or greater' 'Data not reported'
#  'Non-Hispanic White' 'Non-Hispanic Black' 'Hispanic' 'Asian'
#  'Hawaiian/Pacific Islander' 'American Indian/Alaska Native'
#  '2 or more races' 'Other']
#
#
# data_value_Type ['Value']

# %%
df.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               53392
# Data_Value_Type                   0
# Data_Value                     5046
# Data_Value_Alt                 5046
# Data_Value_Footnote_Symbol    48346
# Data_Value_Footnote           48346
# Low_Confidence_Limit           5046
# High_Confidence_Limit          5046
# Sample_Size                    5046
# Total                         51485
# Age(years)                    41954
# Education                     45764
# Gender                        49578
# Income                        40043
# Race/Ethnicity                38136
# GeoLocation                    1008
# ClassID                           0
# TopicID                           0
# ...

# %% [markdown]
# Removing the null values from the dataset

# %%
df = df.dropna(subset=['Sample_Size'])
df.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               48346
# Data_Value_Type                   0
# Data_Value                        0
# Data_Value_Alt                    0
# Data_Value_Footnote_Symbol    48346
# Data_Value_Footnote           48346
# Low_Confidence_Limit              0
# High_Confidence_Limit             0
# Sample_Size                       0
# Total                         46439
# Age(years)                    36908
# Education                     40718
# Gender                        44532
# Income                        34997
# Race/Ethnicity                38136
# GeoLocation                    1008
# ClassID                           0
# TopicID                           0
# ...

# %%
df.shape
# Out:
# (48346, 33)

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
# 3       2011     2011           AL      Alabama
# 4       2011     2011           AL      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=df.corr(),annot=True, lw = 1)
# Out:
# C:\Users\NISHIT\AppData\Local\Temp\ipykernel_24964\2362052783.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),annot=True, lw = 1)
# <Axes: >

# %% [markdown]
# Making final dataset

# %%
df_final = df[['YearStart','YearEnd','LocationDesc','Topic','Question','Data_Value','Sample_Size',
               'Total','Age(years)','Education','Gender','Income','Race/Ethnicity','QuestionID','Stratification1']]

# %%
df_final.head()
# Out:
#    YearStart  YearEnd LocationDesc                    Topic  \
# 0       2011     2011      Alabama  Obesity / Weight Status
# 1       2011     2011      Alabama  Obesity / Weight Status
# 2       2011     2011      Alabama  Obesity / Weight Status
# 3       2011     2011      Alabama  Obesity / Weight Status
# 4       2011     2011      Alabama  Obesity / Weight Status
#
#                                             Question  Data_Value  Sample_Size  \
# 0  Percent of adults aged 18 years and older who ...        32.0       7304.0
# 1  Percent of adults aged 18 years and older who ...        32.3       2581.0
# 2  Percent of adults aged 18 years and older who ...        31.8       4723.0
# 3  Percent of adults aged 18 years and older who ...        33.6       1153.0
# 4  Percent of adults aged 18 years and older who ...        32.8       2402.0
#
#    Total Age(years)              Education  Gender Income Race/Ethnicity  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=df_final.corr(),annot=True, lw = 1)
# Out:
# C:\Users\NISHIT\AppData\Local\Temp\ipykernel_24964\2228833376.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df_final.corr(),annot=True, lw = 1)
# <Axes: >

# %%
distinct_questions = df_final['Question'].unique()
question_to_integer = {question: i + 1 for i, question in enumerate(distinct_questions)}

df_final_copy = df_final.copy()

df_final_copy['question_id'] = df_final_copy['Question'].map(question_to_integer)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=df_final_copy.corr(),annot=True, lw = 1)
# Out:
# C:\Users\NISHIT\AppData\Local\Temp\ipykernel_24964\1137236601.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df_final_copy.corr(),annot=True, lw = 1)
# <Axes: >

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df_final["Income"], y=df_final["Data_Value"])
# Out:
# <Axes: xlabel='Income', ylabel='Data_Value'>

# %%
df_final_copy = df_final_copy[df_final_copy['Topic'] == 'Obesity / Weight Status']
df_final_copy.shape
# Out:
# (16254, 16)

# %%
df_final = df_final[df_final['Topic'] == 'Obesity / Weight Status']
df_final.shape
# Out:
# (16254, 15)

# %%
df_final["Question"].unique()
# Out:
# array(['Percent of adults aged 18 years and older who have obesity',
#        'Percent of adults aged 18 years and older who have an overweight classification'],
#       dtype=object)

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df_final["Age(years)"], y=df_final["Data_Value"], hue=df_final["Question"])
# Out:
# <Axes: xlabel='Age(years)', ylabel='Data_Value'>

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=df_final["Education"], y=df_final["Data_Value"],  hue=df_final["Question"])
# Out:
# <Axes: xlabel='Education', ylabel='Data_Value'>

# %%
df_final['YearStart'].unique()
# Out:
# array([2011, 2012, 2014, 2013, 2015, 2016], dtype=int64)

# %%
df2011 = df_final[df_final['YearStart'] == 2011]
df2011.count()
# Out:
# YearStart          2664
# YearEnd            2664
# LocationDesc       2664
# Topic              2664
# Question           2664
# Data_Value         2664
# Sample_Size        2664
# Total               104
# Age(years)          624
# Education           416
# Gender              208
# Income              728
# Race/Ethnicity      584
# QuestionID         2664
# Stratification1    2664
# dtype: int64

# %%
df2012 = df_final[df_final['YearStart'] == 2012]
df2012.count()
# Out:
# YearStart          2664
# YearEnd            2664
# LocationDesc       2664
# Topic              2664
# Question           2664
# Data_Value         2664
# Sample_Size        2664
# Total               104
# Age(years)          624
# Education           416
# Gender              208
# Income              728
# Race/Ethnicity      584
# QuestionID         2664
# Stratification1    2664
# dtype: int64

# %%
df2013 = df_final[df_final['YearStart'] == 2013]
df2013.count()
# Out:
# YearStart          2688
# YearEnd            2688
# LocationDesc       2688
# Topic              2688
# Question           2688
# Data_Value         2688
# Sample_Size        2688
# Total               106
# Age(years)          636
# Education           424
# Gender              212
# Income              742
# Race/Ethnicity      568
# QuestionID         2688
# Stratification1    2688
# dtype: int64

# %%
df2014 = df_final[df_final['YearStart'] == 2014]
df2014.count()
# Out:
# YearStart          2738
# YearEnd            2738
# LocationDesc       2738
# Topic              2738
# Question           2738
# Data_Value         2738
# Sample_Size        2738
# Total               108
# Age(years)          648
# Education           432
# Gender              216
# Income              756
# Race/Ethnicity      578
# QuestionID         2738
# Stratification1    2738
# dtype: int64

# %%
df2015 = df_final[df_final['YearStart'] == 2015]
df2015.count()
# Out:
# YearStart          2722
# YearEnd            2722
# LocationDesc       2722
# Topic              2722
# Question           2722
# Data_Value         2722
# Sample_Size        2722
# Total               108
# Age(years)          648
# Education           432
# Gender              216
# Income              756
# Race/Ethnicity      562
# QuestionID         2722
# Stratification1    2722
# dtype: int64

# %%
df2016 = df_final[df_final['YearStart'] == 2016]
df2016.count()
# Out:
# YearStart          2778
# YearEnd            2778
# LocationDesc       2778
# Topic              2778
# Question           2778
# Data_Value         2778
# Sample_Size        2778
# Total               110
# Age(years)          660
# Education           440
# Gender              220
# Income              770
# Race/Ethnicity      578
# QuestionID         2778
# Stratification1    2778
# dtype: int64

# %%
df2016 = df2016[(df2016['Stratification1']=='Male')|(df2016['Stratification1']=='Female')]
sort_df2016 = df2016.sort_values('LocationDesc', ascending = [True])
sort_df2016 = sort_df2016[['LocationDesc','Data_Value','Gender']]

# %%
sort_df2016.shape
# Out:
# (220, 3)

# %%
sort_df2016 = sort_df2016.groupby('LocationDesc', as_index=False)

# %%
type(sort_df2016['Data_Value'])
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
#Calculating the mean of the data_value of male and female data only.
mean2016= sum(sort_df2016['Data_Value'])/len(sort_df2016)
print(mean2016)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[218], line 2
#       1 #Calculating the mean of the data_value of male and female data only.
# ----> 2 mean2016= sum(sort_df2016['Data_Value'])/len(sort_df2016)
#       3 print(mean2016)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
# sort_df2016 = sort_df2016.sort_values(['Data_Value'], ascending = [True])
# plt.figure(figsize = (10,15))

# plt.subplot(2,1,1)
# ax=sns.barplot(y=sort_df2016.tail(10).LocationDesc,x=sort_df2016.tail(10).Data_Value,palette="Blues_d")
# ax.set_ylabel('US State')
# ax.set_xlabel('Obesity Rate (%)')
# ax.set_title('10 Most Obese States in 2014')

# plt.plot([mean2016,mean2016],[-1,10], '--',color = 'r')
