# %%
import math
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv')

# %%
df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
# 3       2011     2011           AL      Alabama
# 4       2011     2011           AL      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# ...

# %%
df['Class'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['Question'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(30,20))
sns.heatmap(data=df.corr(),annot=True, lw = 1)
# Out:
# C:\Users\Harshneel\AppData\Local\Temp\ipykernel_17668\2649803166.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),annot=True, lw = 1)
# <Axes: >

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   53392 non-null  int64
#  1   YearEnd                     53392 non-null  int64
#  2   LocationAbbr                53392 non-null  object
#  3   LocationDesc                53392 non-null  object
#  4   Datasource                  53392 non-null  object
#  5   Class                       53392 non-null  object
#  6   Topic                       53392 non-null  object
#  7   Question                    53392 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             53392 non-null  object
#  10  Data_Value                  48346 non-null  float64
#  11  Data_Value_Alt              48346 non-null  float64
#  12  Data_Value_Footnote_Symbol  5046 non-null   object
# ...

# %%
df['YearStart'].unique()
# Out:
# array([2011, 2012, 2014, 2013, 2015, 2016], dtype=int64)

# %%
df['Question'].nunique()
# Out:
# 9

# %%
df['Question'].unique()
# Out:
# array(['Percent of adults aged 18 years and older who have obesity',
#        'Percent of adults aged 18 years and older who have an overweight classification',
#        'Percent of adults who report consuming fruit less than one time daily',
#        'Percent of adults who report consuming vegetables less than one time daily',
#        'Percent of adults who engage in muscle-strengthening activities on 2 or more days a week',
#        'Percent of adults who achieve at least 150 minutes a week of moderate-intensity aerobic physical activity or 75 minutes a week of vigorous-intensity aerobic activity (or an equivalent combination)',
#        'Percent of adults who achieve at least 150 minutes a week of moderate-intensity aerobic physical activity or 75 minutes a week of vigorous-intensity aerobic physical activity and engage in muscle-strengthening activities on 2 or more days a week',
# ...

# %%
df['Datasource'].unique()
# Out:
# array(['Behavioral Risk Factor Surveillance System'], dtype=object)

# %%
df['Class'].nunique()
# Out:
# 3

# %%
df['Class'].unique()
# Out:
# array(['Obesity / Weight Status', 'Fruits and Vegetables',
#        'Physical Activity'], dtype=object)

# %%
df['Topic'].unique()
# Out:
# array(['Obesity / Weight Status', 'Fruits and Vegetables - Behavior',
#        'Physical Activity - Behavior'], dtype=object)

# %%
df['Data_Value'].nunique()
# Out:
# 669

# %%
df['Data_Value_Alt'].nunique()
# Out:
# 669

# %%
df['Data_Value_Footnote'].unique()
# Out:
# array([nan, 'Data not available because sample size is insufficient.',
#        'Data not available because sample size is insufficient.  If data only missing for the confidence interval, the confidence interval was not calculated.'],
#       dtype=object)

# %%
df['StratificationCategory1'].unique()
# Out:
# array(['Total', 'Gender', 'Education', 'Age (years)', 'Income',
#        'Race/Ethnicity'], dtype=object)

# %%
df['Race/Ethnicity'].unique()
# Out:
# array([nan, 'Non-Hispanic White', 'Non-Hispanic Black', 'Hispanic',
#        'Asian', 'Hawaiian/Pacific Islander',
#        'American Indian/Alaska Native', '2 or more races', 'Other'],
#       dtype=object)

# %%
df['Sample_Size'].nunique()
# Out:
# 8123

# %%
df['Sample_Size']
# Out:
# 0        7304.0
# 1        2581.0
# 2        4723.0
# 3        1153.0
# 4        2402.0
#           ...
# 53387       NaN
# 53388       NaN
# 53389       NaN
# 53390       NaN
# 53391       NaN
# Name: Sample_Size, Length: 53392, dtype: float64

# %%
df.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               53392
# Data_Value_Type                   0
# Data_Value                     5046
# Data_Value_Alt                 5046
# Data_Value_Footnote_Symbol    48346
# Data_Value_Footnote           48346
# Low_Confidence_Limit           5046
# High_Confidence_Limit          5046
# Sample_Size                    5046
# Total                         51485
# Age(years)                    41954
# Education                     45764
# Gender                        49578
# Income                        40043
# Race/Ethnicity                38136
# GeoLocation                    1008
# ClassID                           0
# TopicID                           0
# ...

# %%
df = df.dropna(subset=['Sample_Size'])

# %%
df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53382       2016     2016           VI  Virgin Islands
# 53383       2016     2016           VI  Virgin Islands
# 53384       2016     2016           VI  Virgin Islands
# 53385       2016     2016           VI  Virgin Islands
# 53386       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
df.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               48346
# Data_Value_Type                   0
# Data_Value                        0
# Data_Value_Alt                    0
# Data_Value_Footnote_Symbol    48346
# Data_Value_Footnote           48346
# Low_Confidence_Limit              0
# High_Confidence_Limit             0
# Sample_Size                       0
# Total                         46439
# Age(years)                    36908
# Education                     40718
# Gender                        44532
# Income                        34997
# Race/Ethnicity                38136
# GeoLocation                    1008
# ClassID                           0
# TopicID                           0
# ...

# %%
Final_Dataset = df[['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc',
       'Class', 'Topic', 'Question','Data_Value','Sample_Size', 
       'Total', 'Age(years)', 'Education', 'Gender', 'Income',
       'Race/Ethnicity', 'GeoLocation']]

# %%
Final_Dataset
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53382       2016     2016           VI  Virgin Islands
# 53383       2016     2016           VI  Virgin Islands
# 53384       2016     2016           VI  Virgin Islands
# 53385       2016     2016           VI  Virgin Islands
# 53386       2016     2016           VI  Virgin Islands
#
#                          Class                         Topic  \
# 0      Obesity / Weight Status       Obesity / Weight Status
# 1      Obesity / Weight Status       Obesity / Weight Status
# 2      Obesity / Weight Status       Obesity / Weight Status
# ...

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=Final_Dataset["Income"], y=Final_Dataset["Data_Value"])
# Out:
# <Axes: xlabel='Income', ylabel='Data_Value'>

# %%
Final_Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48346 entries, 0 to 53386
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   YearStart       48346 non-null  int64
#  1   YearEnd         48346 non-null  int64
#  2   LocationAbbr    48346 non-null  object
#  3   LocationDesc    48346 non-null  object
#  4   Class           48346 non-null  object
#  5   Topic           48346 non-null  object
#  6   Question        48346 non-null  object
#  7   Data_Value      48346 non-null  float64
#  8   Sample_Size     48346 non-null  float64
#  9   Total           1907 non-null   object
#  10  Age(years)      11438 non-null  object
#  11  Education       7628 non-null   object
#  12  Gender          3814 non-null   object
#  13  Income          13349 non-null  object
#  14  Race/Ethnicity  10210 non-null  object
#  15  GeoLocation     47338 non-null  object
# dtypes: float64(2), int64(2), object(12)
# ...

# %%
Final_Dataset.isnull().sum()
# Out:
# YearStart             0
# YearEnd               0
# LocationAbbr          0
# LocationDesc          0
# Class                 0
# Topic                 0
# Question              0
# Data_Value            0
# Sample_Size           0
# Total             46439
# Age(years)        36908
# Education         40718
# Gender            44532
# Income            34997
# Race/Ethnicity    38136
# GeoLocation        1008
# dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=Final_Dataset["Age(years)"], y=Final_Dataset["Data_Value"])
# Out:
# <Axes: xlabel='Age(years)', ylabel='Data_Value'>

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=Final_Dataset["Education"], y=Final_Dataset["Data_Value"])
# Out:
# <Axes: xlabel='Education', ylabel='Data_Value'>

# %%
Final_Dataset.isnull().sum()
# Out:
# YearStart             0
# YearEnd               0
# LocationAbbr          0
# LocationDesc          0
# Class                 0
# Topic                 0
# Question              0
# Data_Value            0
# Sample_Size           0
# Total             46439
# Age(years)        36908
# Education         40718
# Gender            44532
# Income            34997
# Race/Ethnicity    38136
# GeoLocation        1008
# Year                  0
# dtype: int64

# %%
sns.catplot(data=Final_Dataset,x='Gender',y='Data_Value',kind='box')

# %%
Final_Dataset = Final_Dataset[['Year', 'LocationAbbr', 'LocationDesc',
       'Class', 'Topic', 'Question','Data_Value','Sample_Size', 
       'Total', 'Age(years)', 'Education', 'Gender', 'Income',
       'Race/Ethnicity', 'GeoLocation']]

# %%
Final_Dataset.head()
# Out:
#    Year LocationAbbr LocationDesc                    Class  \
# 0  2011           AL      Alabama  Obesity / Weight Status
# 1  2011           AL      Alabama  Obesity / Weight Status
# 2  2011           AL      Alabama  Obesity / Weight Status
# 3  2011           AL      Alabama  Obesity / Weight Status
# 4  2011           AL      Alabama  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 2  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 3  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 4  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
#
#    Data_Value  Sample_Size  Total Age(years)              Education  Gender  \
# ...

# %%
Final_Dataset.drop(['Class'],axis=1,inplace=True)
# Out:
# C:\Users\Harshneel\AppData\Local\Temp\ipykernel_17668\2981476901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Final_Dataset.drop(['Class'],axis=1,inplace=True)

# %%
Final_Dataset.head()
# Out:
#    Year LocationAbbr LocationDesc                    Topic  \
# 0  2011           AL      Alabama  Obesity / Weight Status
# 1  2011           AL      Alabama  Obesity / Weight Status
# 2  2011           AL      Alabama  Obesity / Weight Status
# 3  2011           AL      Alabama  Obesity / Weight Status
# 4  2011           AL      Alabama  Obesity / Weight Status
#
#                                             Question  Data_Value  Sample_Size  \
# 0  Percent of adults aged 18 years and older who ...        32.0       7304.0
# 1  Percent of adults aged 18 years and older who ...        32.3       2581.0
# 2  Percent of adults aged 18 years and older who ...        31.8       4723.0
# 3  Percent of adults aged 18 years and older who ...        33.6       1153.0
# 4  Percent of adults aged 18 years and older who ...        32.8       2402.0
#
#    Total Age(years)              Education  Gender Income Race/Ethnicity  \
# ...

# %%
Final_Dataset['Age(years)'].unique()
# Out:
# array([nan, '18 - 24', '25 - 34', '35 - 44', '45 - 54', '55 - 64',
#        '65 or older'], dtype=object)

# %%
Final_Dataset['Education'].unique()
# Out:
# array([nan, 'Less than high school', 'High school graduate',
#        'Some college or technical school', 'College graduate'],
#       dtype=object)

# %%
Data = Final_Dataset.loc[Final_Dataset['Topic'] == 'Obesity / Weight Status']

# %%
Data
# Out:
#        Year LocationAbbr    LocationDesc                    Topic  \
# 0      2011           AL         Alabama  Obesity / Weight Status
# 1      2011           AL         Alabama  Obesity / Weight Status
# 2      2011           AL         Alabama  Obesity / Weight Status
# 3      2011           AL         Alabama  Obesity / Weight Status
# 4      2011           AL         Alabama  Obesity / Weight Status
# ...     ...          ...             ...                      ...
# 51842  2016           VI  Virgin Islands  Obesity / Weight Status
# 51843  2016           VI  Virgin Islands  Obesity / Weight Status
# 51844  2016           VI  Virgin Islands  Obesity / Weight Status
# 51845  2016           VI  Virgin Islands  Obesity / Weight Status
# 51846  2016           VI  Virgin Islands  Obesity / Weight Status
#
#                                                 Question  Data_Value  \
# 0      Percent of adults aged 18 years and older who ...        32.0
# ...

# %%
Data['Topic'].unique()
# Out:
# array(['Obesity / Weight Status'], dtype=object)

# %%
Data.isnull().sum()
# Out:
# Year                  0
# LocationAbbr          0
# LocationDesc          0
# Topic                 0
# Question              0
# Data_Value            0
# Sample_Size           0
# Total             15614
# Age(years)        12414
# Education         13694
# Gender            14974
# Income            11774
# Race/Ethnicity    12800
# GeoLocation         336
# dtype: int64

# %%
Data.shape
# Out:
# (16254, 14)

# %%
Data.head()
# Out:
#    Year LocationAbbr LocationDesc                    Topic  \
# 0  2011           AL      Alabama  Obesity / Weight Status
# 1  2011           AL      Alabama  Obesity / Weight Status
# 2  2011           AL      Alabama  Obesity / Weight Status
# 3  2011           AL      Alabama  Obesity / Weight Status
# 4  2011           AL      Alabama  Obesity / Weight Status
#
#                                             Question  Data_Value  Sample_Size  \
# 0  Percent of adults aged 18 years and older who ...        32.0       7304.0
# 1  Percent of adults aged 18 years and older who ...        32.3       2581.0
# 2  Percent of adults aged 18 years and older who ...        31.8       4723.0
# 3  Percent of adults aged 18 years and older who ...        33.6       1153.0
# 4  Percent of adults aged 18 years and older who ...        32.8       2402.0
#
#    Total Age(years)              Education  Gender Income Race/Ethnicity  \
# ...

# %%
data = pd.get_dummies(data=Data,columns=['Total','Age(years)','Education','Gender','Income','Race/Ethnicity'],drop_first=True)

# %%
data.head()
# Out:
#    Year LocationAbbr LocationDesc                    Topic  \
# 0  2011           AL      Alabama  Obesity / Weight Status
# 1  2011           AL      Alabama  Obesity / Weight Status
# 2  2011           AL      Alabama  Obesity / Weight Status
# 3  2011           AL      Alabama  Obesity / Weight Status
# 4  2011           AL      Alabama  Obesity / Weight Status
#
#                                             Question  Data_Value  Sample_Size  \
# 0  Percent of adults aged 18 years and older who ...        32.0       7304.0
# 1  Percent of adults aged 18 years and older who ...        32.3       2581.0
# 2  Percent of adults aged 18 years and older who ...        31.8       4723.0
# 3  Percent of adults aged 18 years and older who ...        33.6       1153.0
# 4  Percent of adults aged 18 years and older who ...        32.8       2402.0
#
#                                GeoLocation  Age(years)_25 - 34  \
# 0  (32.84057112200048, -86.63186076199969)                   0
# ...

# %%
data.shape
# Out:
# (16254, 30)

# %%
data.isnull().sum()
# Out:
# Year                                              0
# LocationAbbr                                      0
# LocationDesc                                      0
# Topic                                             0
# Question                                          0
# Data_Value                                        0
# Sample_Size                                       0
# GeoLocation                                     336
# Age(years)_25 - 34                                0
# Age(years)_35 - 44                                0
# Age(years)_45 - 54                                0
# Age(years)_55 - 64                                0
# Age(years)_65 or older                            0
# Education_High school graduate                    0
# Education_Less than high school                   0
# Education_Some college or technical school        0
# Gender_Male                                       0
# Income_$25,000 - $34,999                          0
# ...

# %%
data.columns
# Out:
# Index(['Year', 'LocationAbbr', 'LocationDesc', 'Topic', 'Question',
#        'Data_Value', 'Sample_Size', 'GeoLocation', 'Age(years)_25 - 34',
#        'Age(years)_35 - 44', 'Age(years)_45 - 54', 'Age(years)_55 - 64',
#        'Age(years)_65 or older', 'Education_High school graduate',
#        'Education_Less than high school',
#        'Education_Some college or technical school', 'Gender_Male',
#        'Income_$25,000 - $34,999', 'Income_$35,000 - $49,999',
#        'Income_$50,000 - $74,999', 'Income_$75,000 or greater',
#        'Income_Data not reported', 'Income_Less than $15,000',
#        'Race/Ethnicity_American Indian/Alaska Native', 'Race/Ethnicity_Asian',
#        'Race/Ethnicity_Hawaiian/Pacific Islander', 'Race/Ethnicity_Hispanic',
#        'Race/Ethnicity_Non-Hispanic Black',
#        'Race/Ethnicity_Non-Hispanic White', 'Race/Ethnicity_Other'],
#       dtype='object')

# %%
X = data[['Year','Age(years)_25 - 34', 'Age(years)_35 - 44', 'Age(years)_45 - 54',
       'Age(years)_55 - 64', 'Age(years)_65 or older',
       'Education_High school graduate', 'Education_Less than high school',
       'Education_Some college or technical school', 'Gender_Male',
       'Income_$25,000 - $34,999', 'Income_$35,000 - $49,999',
       'Income_$50,000 - $74,999', 'Income_$75,000 or greater',
       'Income_Data not reported', 'Income_Less than $15,000',
       'Race/Ethnicity_American Indian/Alaska Native', 'Race/Ethnicity_Asian',
       'Race/Ethnicity_Hawaiian/Pacific Islander', 'Race/Ethnicity_Hispanic',
       'Race/Ethnicity_Non-Hispanic Black',
       'Race/Ethnicity_Non-Hispanic White', 'Race/Ethnicity_Other']]

# %%
y = data[['Data_Value']]

# %%
X.head()
# Out:
#    Year  Age(years)_25 - 34  Age(years)_35 - 44  Age(years)_45 - 54  \
# 0  2011                   0                   0                   0
# 1  2011                   0                   0                   0
# 2  2011                   0                   0                   0
# 3  2011                   0                   0                   0
# 4  2011                   0                   0                   0
#
#    Age(years)_55 - 64  Age(years)_65 or older  Education_High school graduate  \
# 0                   0                       0                               0
# 1                   0                       0                               0
# 2                   0                       0                               0
# 3                   0                       0                               0
# 4                   0                       0                               1
#
#    Education_Less than high school  \
# 0                                0
# ...

# %%
y.head()
# Out:
#    Data_Value
# 0        32.0
# 1        32.3
# 2        31.8
# 3        33.6
# 4        32.8

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.metrics import mean_squared_error
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
rng = np.random.RandomState(0)

# %%
alpha = 1.0
ridge = Ridge(alpha=alpha)
ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
y_pred_train = ridge.predict(X_train)

# %%
r2_train = ridge.score(X_train, y_train)
rmse_train =  np.sqrt(mean_squared_error(y_train, y_pred_train))
print(r2_train)
print(rmse_train)
# Out:
# 0.1954130044952206
# 5.949464172305267

# %%
y_pred = ridge.predict(X_test)

# %%
y_pred
# Out:
# array([[33.28242327],
#        [35.50387307],
#        [36.04987926],
#        ...,
#        [35.50387307],
#        [29.48947166],
#        [32.05235422]])

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = ridge.score(X_test, y_test)

# %%
print(mse)
print(r2)
# Out:
# 34.46651544270792
# 0.21193605683807237

# %%
rmse = np.sqrt(mse)
print(rmse)
# Out:
# 5.870818975467386

# %%
alphas = [0.001, 0.01, 0.1, 1.0, 10.0,3.0]

# %%
param_grid = {'alpha': alphas}
grid_search = GridSearchCV(Ridge(), param_grid, cv=5)
grid_search.fit(X_train, y_train)

best_alpha = grid_search.best_params_['alpha']
best_ridge = grid_search.best_estimator_

# %%
y_pred2 = best_ridge.predict(X_test)
rmse2 = np.sqrt(mean_squared_error(y_test, y_pred2))

# %%
print(rmse2)
# Out:
# 5.870818975467386

# %%
alpha2 = 0.001
ridge2 = Ridge(alpha=alpha2)
ridge2.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.001)

# %%
y_pred3 = ridge2.predict(X_test)

# %%
rmse3 = np.sqrt(mean_squared_error(y_test, y_pred3))

# %%
print(rmse3)
# Out:
# 5.8709694132460415
